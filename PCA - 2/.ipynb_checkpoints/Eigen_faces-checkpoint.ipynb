# %%
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
olive = datasets.fetch_olivetti_faces()
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to C:\Users\Piyush Pravin\scikit_learn_data

# %%
olive.keys()
# Out:
# dict_keys(['data', 'images', 'target', 'DESCR'])

# %%
olive["data"].shape
# Out:
# (400, 4096)

# %%
olive["images"].shape
# Out:
# (400, 64, 64)

# %%
fig = plt.figure(figsize=(8,8))
for i in range(64):
    ax = fig.add_subplot(8, 8, i+1)
    ax.imshow(olive.images[i], cmap = plt.cm.bone)
plt.show()

# %%
x = olive.data
y = olive.target

# %%
pca = PCA()
pca.fit(x)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
pca.components_.shape
# Out:
# (400, 4096)

# %%
k = 0
total = sum(pca.explained_variance_)
currentSum = 0
while currentSum/total<0.99:
    currentSum += pca.explained_variance_[k]
    k+=1
k
# Out:
# 260

# %%
pca = PCA(n_components = k)
transformed_data = pca.fit_transform(x)
transformed_data.shape
# Out:
# (400, 260)

# %%
x_approx = pca.inverse_transform(transformed_data)
x_approx.shape
# Out:
# (400, 4096)

# %%
x_aprrox_images = x_approx.reshape((400,64,64))

# %%
fig = plt.figure(figsize=(8,8))
for i in range(64):
    ax = fig.add_subplot(8, 8, i+1)
    ax.imshow(x_aprrox_images[i], cmap = plt.cm.bone)
plt.show()
