# %%
import cifar10
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

# %%
cifar10.data_path = "data/CIFAR-10/"

# %%
cifar10.maybe_download_and_extract()
# Out:
# Data has apparently already been downloaded and unpacked.

# %%
class_names = cifar10.load_class_names()
class_names
# Out:
# Loading data: data/CIFAR-10/cifar-10-batches-py/batches.meta
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %%
images_train, cls_train, labels_train = cifar10.load_training_data()
images_test, cls_test, labels_test = cifar10.load_test_data()
# Out:
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_1
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_2
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_3
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_4
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_5
# Loading data: data/CIFAR-10/cifar-10-batches-py/test_batch

# %%
print(images_train.shape)
print(cls_train.shape)
print(labels_train.shape)
# Out:
# (50000, 32, 32, 3)
# (50000,)
# (50000, 10)

# %%
images_train_reshaped = images_train.reshape((50000,32*32*3))
images_train_reshaped.shape
# Out:
# (50000, 3072)

# %%
fig = plt.figure(figsize=(10,10))
for i in range(100):
    ax = fig.add_subplot(10,10,i+1)
    ax.imshow(images_train[i])
plt.show()

# %%
pca = PCA()
pca.fit(images_train_reshaped)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
k = 0
total = sum(pca.explained_variance_)
currentSum = 0
while currentSum/total<0.99:
    currentSum += pca.explained_variance_[k]
    k+=1
k
# Out:
# 658

# %%
pca = PCA(n_components=k)
images_train_transformed = pca.fit_transform(images_train_reshaped)
images_train_transformed.shape
# Out:
# (50000, 658)

# %%
images_approx = pca.inverse_transform(images_train_transformed)
images_approx = images_approx.reshape((50000,32,32,3))
images_approx.shape
# Out:
# (50000, 32, 32, 3)

# %%
fig = plt.figure(figsize=(10,10))
for i in range(100):
    ax = fig.add_subplot(10,10,i+1)
    ax.imshow(images_approx[i])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
images_test_reshaped = images_test.reshape((10000,32*32*3))
images_test_reshaped.shape
# Out:
# (10000, 3072)

# %%
images_test_transformed = pca.transform(images_test_reshaped)
images_test_transformed.shape
# Out:
# (10000, 658)

# %%
rf_clf = RandomForestClassifier()
rf_clf.fit(images_train_transformed,cls_train)
cls_pred = rf_clf.predict(images_test_transformed)
print(classification_report(cls_test,cls_pred))
# Out:
# C:\Users\Piyush Pravin\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
#               precision    recall  f1-score   support
#
#            0       0.24      0.41      0.31      1000
#            1       0.24      0.33      0.28      1000
#            2       0.19      0.26      0.22      1000
#            3       0.17      0.19      0.18      1000
#            4       0.24      0.23      0.24      1000
#            5       0.25      0.20      0.22      1000
#            6       0.27      0.20      0.23      1000
#            7       0.24      0.16      0.19      1000
#            8       0.39      0.31      0.34      1000
#            9       0.29      0.17      0.21      1000
#
#     accuracy                           0.25     10000
#    macro avg       0.25      0.25      0.24     10000
# weighted avg       0.25      0.25      0.24     10000

# %%
clf = SVC()
grid={'C':[1e2,1e4,1e1,5e3,1e3,5e2],
      'gamma':[1e-3,1e-2,5e-3,5e-2,1e-4,1e-5]}

svm = GridSearchCV(clf,grid, n_jobs=-1)

svm.fit(images_train_transformed,cls_train)

y_pred = svm.predict(images_test_transformed)

print(svm.score(cls_test,y_pred))
# Out:
# C:\Users\Piyush Pravin\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)

# %%
predictions = []
for i in range(len(cls_pred)):
    predictions.append(class_names[cls_pred[i]])
predictions
# Out:
# ['deer',
#  'ship',
#  'airplane',
#  'airplane',
#  'bird',
#  'bird',
#  'frog',
#  'deer',
#  'ship',
#  'automobile',
#  'airplane',
#  'automobile',
#  'horse',
#  'dog',
#  'automobile',
#  'horse',
#  'dog',
#  'automobile',
#  'truck',
#  'frog',
#  'horse',
#  'bird',
#  'airplane',
#  'dog',
#  'deer',
#  'cat',
#  'horse',
#  'truck',
#  'dog',
#  'deer',
#  'frog',
#  'dog',
#  'bird',
#  'automobile',
#  'automobile',
#  'cat',
#  'automobile',
#  'truck',
#  'bird',
#  'deer',
#  'horse',
#  'deer',
#  'bird',
#  'automobile',
#  'airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'deer',
#  'frog',
#  'bird',
#  'dog',
#  'horse',
#  'airplane',
#  'ship',
#  'dog',
#  'dog',
#  'airplane',
#  'deer',
#  'deer',
#  'horse',
#  'airplane',
#  'automobile',
#  'bird',
#  'automobile',
#  'cat',
#  'ship',
#  'dog',
#  'frog',
#  'deer',
#  'bird',
#  'airplane',
#  'ship',
#  'frog',
#  'bird',
#  'truck',
#  'dog',
#  'automobile',
#  'deer',
#  'airplane',
#  'dog',
#  'bird',
#  'bird',
#  'airplane',
#  'bird',
#  'airplane',
#  'ship',
#  'airplane',
#  'airplane',
#  'airplane',
#  'cat',
#  'airplane',
#  'deer',
#  'deer',
#  'airplane',
#  'deer',
#  'ship',
#  'frog',
#  'airplane',
#  'cat',
#  'deer',
#  'ship',
#  'deer',
#  'automobile',
#  'airplane',
#  'deer',
#  'frog',
#  'automobile',
#  'horse',
#  'deer',
#  'ship',
#  'deer',
#  'deer',
#  'automobile',
#  'cat',
#  'airplane',
#  'bird',
#  'bird',
#  'deer',
#  'bird',
#  'frog',
#  'truck',
#  'cat',
#  'dog',
#  'frog',
#  'ship',
#  'bird',
#  'truck',
#  'cat',
#  'bird',
#  'truck',
#  'ship',
#  'cat',
#  'airplane',
#  'dog',
#  'cat',
#  'airplane',
#  'bird',
#  'ship',
#  'frog',
#  'ship',
#  'bird',
#  'cat',
#  'cat',
#  'horse',
#  'airplane',
#  'automobile',
#  'cat',
#  'bird',
#  'horse',
#  'cat',
#  'frog',
#  'truck',
#  'airplane',
#  'cat',
#  'airplane',
#  'ship',
#  'cat',
#  'deer',
#  'cat',
#  'frog',
#  'bird',
#  'bird',
#  'truck',
#  'airplane',
#  'ship',
#  'cat',
#  'airplane',
#  'truck',
#  'frog',
#  'horse',
#  'airplane',
#  'automobile',
#  'bird',
#  'frog',
#  'bird',
#  'frog',
#  'deer',
#  'automobile',
#  'automobile',
#  'airplane',
#  'automobile',
#  'frog',
#  'airplane',
#  'ship',
#  'bird',
#  'frog',
#  'airplane',
#  'bird',
#  'frog',
#  'frog',
#  'frog',
#  'cat',
#  'bird',
#  'bird',
#  'ship',
#  'ship',
#  'dog',
#  'deer',
#  'cat',
#  'truck',
#  'ship',
#  'cat',
#  'dog',
#  'cat',
#  'ship',
#  'deer',
#  'dog',
#  'airplane',
#  'bird',
#  'dog',
#  'airplane',
#  'airplane',
#  'automobile',
#  'bird',
#  'ship',
#  'ship',
#  'deer',
#  'deer',
#  'horse',
#  'frog',
#  'automobile',
#  'cat',
#  'bird',
#  'bird',
#  'ship',
#  'cat',
#  'dog',
#  'automobile',
#  'dog',
#  'automobile',
#  'bird',
#  'airplane',
#  'airplane',
#  'ship',
#  'bird',
#  'ship',
#  'bird',
#  'dog',
#  'automobile',
#  'bird',
#  'airplane',
#  'truck',
#  'airplane',
#  'dog',
#  'bird',
#  'ship',
#  'airplane',
#  'cat',
#  'automobile',
#  'cat',
#  'automobile',
#  'automobile',
#  'bird',
#  'airplane',
#  'bird',
#  'frog',
#  'ship',
#  'deer',
#  'dog',
#  'airplane',
#  'bird',
#  'ship',
#  'automobile',
#  'ship',
#  'bird',
#  'frog',
#  'airplane',
#  'airplane',
#  'automobile',
#  'bird',
#  'bird',
#  'dog',
#  'automobile',
#  'airplane',
#  'bird',
#  'horse',
#  'cat',
#  'dog',
#  'deer',
#  'frog',
#  'airplane',
#  'truck',
#  'truck',
#  'cat',
#  'automobile',
#  'ship',
#  'frog',
#  'truck',
#  'automobile',
#  'deer',
#  'automobile',
#  'truck',
#  'cat',
#  'deer',
#  'automobile',
#  'airplane',
#  'airplane',
#  'cat',
#  'frog',
#  'frog',
#  'airplane',
#  'airplane',
#  'ship',
#  'automobile',
#  'frog',
#  'bird',
#  'dog',
#  'deer',
#  'ship',
#  'cat',
#  'airplane',
#  'airplane',
#  'cat',
#  'airplane',
#  'airplane',
#  'truck',
#  'horse',
#  'dog',
#  'automobile',
#  'dog',
#  'deer',
#  'deer',
#  'automobile',
#  'frog',
#  'horse',
#  'cat',
#  'horse',
#  'frog',
#  'bird',
#  'frog',
#  'airplane',
#  'bird',
#  'automobile',
#  'cat',
#  'cat',
#  'ship',
#  'airplane',
#  'airplane',
#  'frog',
#  'cat',
#  'airplane',
#  'automobile',
#  'airplane',
#  'horse',
#  'deer',
#  'frog',
#  'ship',
#  'dog',
#  'airplane',
#  'automobile',
#  'automobile',
#  'frog',
#  'deer',
#  'frog',
#  'bird',
#  'deer',
#  'horse',
#  'airplane',
#  'frog',
#  'dog',
#  'ship',
#  'truck',
#  'automobile',
#  'horse',
#  'truck',
#  'automobile',
#  'airplane',
#  'automobile',
#  'bird',
#  'airplane',
#  'ship',
#  'deer',
#  'bird',
#  'automobile',
#  'truck',
#  'automobile',
#  'ship',
#  'deer',
#  'frog',
#  'truck',
#  'airplane',
#  'ship',
#  'bird',
#  'airplane',
#  'airplane',
#  'deer',
#  'bird',
#  'bird',
#  'cat',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'frog',
#  'cat',
#  'bird',
#  'truck',
#  'airplane',
#  'airplane',
#  'airplane',
#  'bird',
#  'ship',
#  'deer',
#  'frog',
#  'dog',
#  'airplane',
#  'airplane',
#  'bird',
#  'airplane',
#  'airplane',
#  'bird',
#  'frog',
#  'automobile',
#  'ship',
#  'horse',
#  'automobile',
#  'ship',
#  'deer',
#  'bird',
#  'deer',
#  'ship',
#  'horse',
#  'bird',
#  'truck',
#  'cat',
#  'cat',
#  'truck',
#  'airplane',
#  'bird',
#  'deer',
#  'cat',
#  'bird',
#  'horse',
#  'bird',
#  'bird',
#  'deer',
#  'horse',
#  'bird',
#  'ship',
#  'cat',
#  'horse',
#  'automobile',
#  'cat',
#  'automobile',
#  'ship',
#  'ship',
#  'bird',
#  'bird',
#  'ship',
#  'ship',
#  'cat',
#  'horse',
#  'dog',
#  'ship',
#  'deer',
#  'deer',
#  'deer',
#  'ship',
#  'automobile',
#  'horse',
#  'cat',
#  'dog',
#  'cat',
#  'ship',
#  'deer',
#  'automobile',
#  'truck',
#  'bird',
#  'airplane',
#  'automobile',
#  'airplane',
#  'bird',
#  'automobile',
#  'frog',
#  'bird',
#  'bird',
#  'bird',
#  'ship',
#  'airplane',
#  'airplane',
#  'ship',
#  'cat',
#  'dog',
#  'deer',
#  'truck',
#  'automobile',
#  'truck',
#  'airplane',
#  'cat',
#  'dog',
#  'bird',
#  'automobile',
#  'airplane',
#  'airplane',
#  'automobile',
#  'horse',
#  'bird',
#  'dog',
#  'automobile',
#  'deer',
#  'horse',
#  'deer',
#  'cat',
#  'bird',
#  'cat',
#  'deer',
#  'cat',
#  'deer',
#  'cat',
#  'frog',
#  'automobile',
#  'truck',
#  'bird',
#  'airplane',
#  'cat',
#  'airplane',
#  'dog',
#  'bird',
#  'cat',
#  'horse',
#  'horse',
#  'airplane',
#  'airplane',
#  'dog',
#  'horse',
#  'airplane',
#  'automobile',
#  'deer',
#  'airplane',
#  'truck',
#  'bird',
#  'airplane',
#  'horse',
#  'automobile',
#  'deer',
#  'deer',
#  'airplane',
#  'automobile',
#  'horse',
#  'airplane',
#  'frog',
#  'dog',
#  'cat',
#  'horse',
#  'automobile',
#  'automobile',
#  'deer',
#  'dog',
#  'cat',
#  'bird',
#  'airplane',
#  'airplane',
#  'deer',
#  'ship',
#  'cat',
#  'automobile',
#  'cat',
#  'deer',
#  'ship',
#  'bird',
#  'frog',
#  'bird',
#  'deer',
#  'ship',
#  'horse',
#  'cat',
#  'airplane',
#  'horse',
#  'bird',
#  'bird',
#  'automobile',
#  'automobile',
#  'cat',
#  'frog',
#  'deer',
#  'airplane',
#  'airplane',
#  'automobile',
#  'deer',
#  'automobile',
#  'dog',
#  'deer',
#  'automobile',
#  'cat',
#  'cat',
#  'deer',
#  'ship',
#  'deer',
#  'ship',
#  'automobile',
#  'bird',
#  'frog',
#  'automobile',
#  'automobile',
#  'bird',
#  'cat',
#  'automobile',
#  'frog',
#  'deer',
#  'truck',
#  'horse',
#  'dog',
#  'frog',
#  'cat',
#  'automobile',
#  'deer',
#  'cat',
#  'truck',
#  'deer',
#  'airplane',
#  'ship',
#  'ship',
#  'dog',
#  'airplane',
#  'horse',
#  'automobile',
#  'horse',
#  'automobile',
#  'deer',
#  'cat',
#  'cat',
#  'airplane',
#  'airplane',
#  'automobile',
#  'automobile',
#  'deer',
#  'automobile',
#  'bird',
#  'airplane',
#  'deer',
#  'frog',
#  'cat',
#  'cat',
#  'cat',
#  'truck',
#  'frog',
#  'truck',
#  'automobile',
#  'cat',
#  'horse',
#  'airplane',
#  'automobile',
#  'bird',
#  'airplane',
#  'bird',
#  'deer',
#  'ship',
#  'deer',
#  'automobile',
#  'truck',
#  'frog',
#  'frog',
#  'truck',
#  'airplane',
#  'cat',
#  'automobile',
#  'deer',
#  'frog',
#  'truck',
#  'truck',
#  'horse',
#  'frog',
#  'dog',
#  'truck',
#  'deer',
#  'ship',
#  'truck',
#  'bird',
#  'cat',
#  'airplane',
#  'dog',
#  'cat',
#  'airplane',
#  'deer',
#  'frog',
#  'horse',
#  'airplane',
#  'ship',
#  'ship',
#  'frog',
#  'airplane',
#  'automobile',
#  'truck',
#  'cat',
#  'airplane',
#  'dog',
#  'airplane',
#  'frog',
#  'bird',
#  'cat',
#  'horse',
#  'ship',
#  'dog',
#  'dog',
#  'automobile',
#  'frog',
#  'deer',
#  'frog',
#  'truck',
#  'airplane',
#  'frog',
#  'airplane',
#  'horse',
#  'deer',
#  'frog',
#  'bird',
#  'truck',
#  'ship',
#  'automobile',
#  'ship',
#  'airplane',
#  'ship',
#  'horse',
#  'dog',
#  'bird',
#  'automobile',
#  'cat',
#  'ship',
#  'deer',
#  'ship',
#  'ship',
#  'automobile',
#  'ship',
#  'ship',
#  'automobile',
#  'horse',
#  'deer',
#  'frog',
#  'dog',
#  'truck',
#  'truck',
#  'dog',
#  'bird',
#  'bird',
#  'airplane',
#  'bird',
#  'automobile',
#  'automobile',
#  'dog',
#  'cat',
#  'automobile',
#  'airplane',
#  'horse',
#  'bird',
#  'deer',
#  'deer',
#  'airplane',
#  'cat',
#  'horse',
#  'airplane',
#  'automobile',
#  'automobile',
#  'deer',
#  'deer',
#  'deer',
#  'ship',
#  'bird',
#  'truck',
#  'frog',
#  'dog',
#  'cat',
#  'bird',
#  'horse',
#  'bird',
#  'ship',
#  'frog',
#  'automobile',
#  'airplane',
#  'automobile',
#  'ship',
#  'airplane',
#  'cat',
#  'airplane',
#  'deer',
#  'automobile',
#  'cat',
#  'deer',
#  'automobile',
#  'horse',
#  'dog',
#  'automobile',
#  'frog',
#  'automobile',
#  'airplane',
#  'cat',
#  'deer',
#  'bird',
#  'airplane',
#  'airplane',
#  'automobile',
#  'airplane',
#  'bird',
#  'bird',
#  'automobile',
#  'deer',
#  'bird',
#  'horse',
#  'deer',
#  'cat',
#  'cat',
#  'bird',
#  'airplane',
#  'deer',
#  'bird',
#  'bird',
#  'deer',
#  'airplane',
#  'deer',
#  'automobile',
#  'deer',
#  'airplane',
#  'bird',
#  'ship',
#  'ship',
#  'frog',
#  'dog',
#  'bird',
#  'truck',
#  'ship',
#  'deer',
#  'truck',
#  'ship',
#  'deer',
#  'cat',
#  'frog',
#  'dog',
#  'bird',
#  'airplane',
#  'cat',
#  'cat',
#  'bird',
#  'airplane',
#  'dog',
#  'automobile',
#  'ship',
#  'airplane',
#  'automobile',
#  'airplane',
#  'horse',
#  'cat',
#  'automobile',
#  'bird',
#  'truck',
#  'bird',
#  'horse',
#  'horse',
#  'deer',
#  'bird',
#  'dog',
#  'truck',
#  'ship',
#  'automobile',
#  'deer',
#  'frog',
#  'horse',
#  'airplane',
#  'horse',
#  'bird',
#  'bird',
#  'automobile',
#  'frog',
#  'cat',
#  'airplane',
#  'ship',
#  'frog',
#  'horse',
#  'horse',
#  'airplane',
#  'deer',
#  'airplane',
#  'deer',
#  'bird',
#  'bird',
#  'ship',
#  'frog',
#  'ship',
#  'frog',
#  'airplane',
#  'airplane',
#  'ship',
#  'cat',
#  'frog',
#  'automobile',
#  'airplane',
#  'truck',
#  'dog',
#  'cat',
#  'deer',
#  'airplane',
#  'deer',
#  'horse',
#  'truck',
#  'automobile',
#  'frog',
#  'bird',
#  'bird',
#  'cat',
#  'dog',
#  'bird',
#  'bird',
#  'deer',
#  'bird',
#  'ship',
#  'ship',
#  'airplane',
#  'bird',
#  'ship',
#  'airplane',
#  'horse',
#  'frog',
#  'bird',
#  'bird',
#  'truck',
#  'truck',
#  'ship',
#  'ship',
#  'airplane',
#  'bird',
#  'horse',
#  'automobile',
#  'automobile',
#  'airplane',
#  'bird',
#  'ship',
#  'automobile',
#  'bird',
#  'airplane',
#  'airplane',
#  'bird',
#  'bird',
#  'dog',
#  'automobile',
#  'truck',
#  'dog',
#  'cat',
#  'automobile',
#  'deer',
#  'automobile',
#  'horse',
#  'horse',
#  'horse',
#  'frog',
#  'ship',
#  'cat',
#  'airplane',
#  'dog',
#  'frog',
#  'bird',
#  'airplane',
#  'truck',
#  'deer',
#  'frog',
#  'deer',
#  'bird',
#  'airplane',
#  'frog',
#  'automobile',
#  'truck',
#  'airplane',
#  'automobile',
#  'truck',
#  'frog',
#  'frog',
#  'deer',
#  'bird',
#  'deer',
#  'automobile',
#  'automobile',
#  'bird',
#  'frog',
#  'bird',
#  'automobile',
#  'horse',
#  'airplane',
#  'airplane',
#  'ship',
#  'truck',
#  'automobile',
#  'bird',
#  'airplane',
#  'ship',
#  'bird',
#  'bird',
#  'airplane',
#  'dog',
#  'horse',
#  'dog',
#  'airplane',
#  'dog',
#  'cat',
#  'ship',
#  'airplane',
#  'dog',
#  'cat',
#  'bird',
#  'truck',
#  'dog',
#  'ship',
#  ...]

# %%
np.savetxt("predictions.csv", predictions, delimiter=',', fmt="%s")
